# %%
# !nvidia-smi --query-gpu=name,compute_cap --format=csv,noheader
# Out:
# Tesla T4, 7.5

# %%
# !nvcc -O2 -arch=sm_75 -o sim AgentSim.cu
# Out:
# AgentSim.cu(32): warning #177-D: variable "AGENT_RADIUS" was declared but never referenced
#   static constexpr float AGENT_RADIUS = 5.f;
#                          ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"

# %%
# !./sim
# Out:
# AgentSim CUDA — 500 agents, world 1280×720
# Building flow field... done (1508 cells, 25 px/cell)
#
# Frame   SimTime  Alive   GPU ms/frame
# ------  -------  ------  ------------
#      0     0.0 s     500  0.121
#     60     1.0 s     500  0.125
#    120     2.0 s     500  0.150
#    180     3.0 s     500  0.164
#    240     4.0 s     500  0.174
#    300     5.0 s     500  0.200
#    360     6.0 s     500  0.198
#    420     7.0 s     500  0.201
#    480     8.0 s     491  0.195
#    540     9.0 s     478  0.172
#    600    10.0 s     469  0.148
#    660    11.0 s     447  0.159
#    720    12.0 s     429  0.157
#    780    13.0 s     413  0.159
#    840    14.0 s     401  0.184
#    900    15.0 s     393  0.158
#    960    16.0 s     388  0.166
#   1020    17.0 s     374  0.110
#   1080    18.0 s     364  0.124
#   1140    19.0 s     356  0.134
#   1200    20.0 s     348  0.116
#   1260    21.0 s     339  0.103
#   1320    22.0 s     331  0.109
#   1380    23.0 s     326  0.108
# ...

# %%
# !./sim --cpu
# Out:
# AgentSim CPU — 500 agents, world 1280×720
# Building flow field... done (1508 cells, 25 px/cell)
#
# Frame   SimTime  Alive   ms/frame
# ------  -------  ------  --------
#      0     0.0 s     500  1.261
#     60     1.0 s     500  0.374
#    120     2.0 s     500  0.492
#    180     3.0 s     500  0.579
#    240     4.0 s     500  0.620
#    300     5.0 s     500  0.643
#    360     6.0 s     500  0.865
#    420     7.0 s     500  0.842
#    480     8.0 s     497  0.604
#    540     9.0 s     494  0.683
#    600    10.0 s     489  0.866
#    660    11.0 s     484  0.880
#    720    12.0 s     479  0.754
#    780    13.0 s     474  0.756
#    840    14.0 s     469  0.640
#    900    15.0 s     462  0.644
#    960    16.0 s     456  0.643
#   1020    17.0 s     450  0.652
#   1080    18.0 s     443  0.709
#   1140    19.0 s     437  0.661
#   1200    20.0 s     430  0.746
#   1260    21.0 s     423  0.662
#   1320    22.0 s     417  0.706
#   1380    23.0 s     411  0.650
# ...
