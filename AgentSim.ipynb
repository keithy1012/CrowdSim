# %%
# !nvidia-smi --query-gpu=name,compute_cap --format=csv,noheader
# Out:
# Tesla T4, 7.5

# %%
# !nvcc -O2 -arch=sm_75 -o sim AgentSim.cu
# Out:
# AgentSim.cu(32): warning #177-D: variable "AGENT_RADIUS" was declared but never referenced
#   static constexpr float AGENT_RADIUS = 5.f;
#                          ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"

# %%
# !./sim
# Out:
# AgentSim CUDA — 10000 agents, world 1280×720
# Building flow field... done (1508 cells, 25 px/cell)
#
# Frame   SimTime  Alive   GPU ms/frame
# ------  -------  ------  ------------
#      0     0.0 s   10000  0.411
#     60     1.0 s   10000  0.419
#    120     2.0 s   10000  0.448
#    180     3.0 s   10000  0.469
#    240     4.0 s   10000  0.508
#    300     5.0 s   10000  0.543
#    360     6.0 s   10000  0.385
#    420     7.0 s    9999  0.399
#    480     8.0 s    9994  0.441
#    540     9.0 s    9987  0.455
#    600    10.0 s    9980  0.459
#    660    11.0 s    9973  0.491
#    720    12.0 s    9967  0.508
#    780    13.0 s    9957  0.539
#    840    14.0 s    9948  0.559
#    900    15.0 s    9940  0.610
#    960    16.0 s    9931  0.623
#   1020    17.0 s    9924  0.647
#   1080    18.0 s    9916  0.693
#   1140    19.0 s    9907  0.711
#   1200    20.0 s    9900  0.758
#   1260    21.0 s    9892  0.811
#   1320    22.0 s    9885  0.868
#   1380    23.0 s    9875  0.890
# ...

# %%
# !./sim --cpu
# Out:
# AgentSim CPU — 10000 agents, world 1280×720
# Building flow field... done (1508 cells, 25 px/cell)
#
# Frame   SimTime  Alive   ms/frame
# ------  -------  ------  --------
#      0     0.0 s   10000  49.029
#     60     1.0 s   10000  47.416
#    120     2.0 s   10000  48.034
#    180     3.0 s   10000  49.669
#    240     4.0 s   10000  53.432
#    300     5.0 s   10000  51.893
#    360     6.0 s   10000  53.657
#    420     7.0 s    9999  56.461
#    480     8.0 s    9997  85.735
#    540     9.0 s    9994  60.131
#    600    10.0 s    9988  61.975
#    660    11.0 s    9983  88.926
#    720    12.0 s    9978  68.963
#    780    13.0 s    9972  69.311
#    840    14.0 s    9967  102.838
#    900    15.0 s    9961  79.783
#    960    16.0 s    9955  78.474
#   1020    17.0 s    9948  93.658
#   1080    18.0 s    9941  94.076
#   1140    19.0 s    9935  90.750
#   1200    20.0 s    9928  94.427
#   1260    21.0 s    9921  97.438
#   1320    22.0 s    9915  101.677
# ...
